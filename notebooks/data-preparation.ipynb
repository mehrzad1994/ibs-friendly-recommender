# %%
# working with recipe dataset

# %%
#import libraries
import numpy as np
import pandas as pd

import nltk
import string
import ast
import re
import unidecode

nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\12266\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
#load the dataset
recipe_data= pd.read_csv("../dataset/raw/dataset_ingredients&recepies\Food Ingredients and Recipe Dataset with Image Name Mapping.csv")
#convert dataset to a dataframe
recipe_df=pd.DataFrame(recipe_data)

# %%
#explore the data frame

#get the size of dataframe
rownum= recipe_df.shape[0]
colnum= recipe_df.shape[1]
print('number of rows in the dataset:',rownum,'\nnumber of columns in the dataset:',colnum)

# print first 5 rows
print(recipe_df.head())
# Out:
# number of rows in the dataset: 13501
# number of columns in the dataset: 6
#    Unnamed: 0                                              Title  \
# 0           0  Miso-Butter Roast Chicken With Acorn Squash Pa...
# 1           1                    Crispy Salt and Pepper Potatoes
# 2           2                        Thanksgiving Mac and Cheese
# 3           3                 Italian Sausage and Bread Stuffing
# 4           4                                       Newton's Law
#
#                                          Ingredients  \
# 0  ['1 (3½–4-lb.) whole chicken', '2¾ tsp. kosher...
# 1  ['2 large egg whites', '1 pound new potatoes (...
# 2  ['1 cup evaporated milk', '1 cup whole milk', ...
# 3  ['1 (¾- to 1-pound) round Italian loaf, cut in...
# 4  ['1 teaspoon dark brown sugar', '1 teaspoon ho...
#
#                                         Instructions  \
# 0  Pat chicken dry with paper towels, season all ...
# 1  Preheat oven to 400°F and line a rimmed baking...
# ...

# %%
#print the values of each column
print(recipe_df.columns.values)
# Out:
# ['Unnamed: 0' 'Title' 'Ingredients' 'Instructions' 'Image_Name'
#  'Cleaned_Ingredients']

# %%
#more information about the title column

#title value count
print('title value count:')
print(recipe_df['Title'].value_counts())

#print(f'Count including NaNs: {len(titles)}')
print('title describe:')
print(recipe_df['Title'].describe())
# Out:
# title value count:
# Potato Latkes                                                          5
# French 75                                                              5
# Chopped Salad                                                          4
# Pickled Red Onions                                                     4
# Sazerac                                                                4
#                                                                       ..
# Cabbage and Jicama Slaw                                                1
# Za'atar Roast Chicken with Green Tahini Sauce                          1
# Grilled Corn with Miso Butter                                          1
# Grilled Lettuces with Crème Fraîche and Avocado                        1
# Mexican Poblano, Spinach, and Black Bean "Lasagne" with Goat Cheese    1
# Name: Title, Length: 13305, dtype: int64
# title describe:
# count             13496
# unique            13305
# top       Potato Latkes
# ...

# %%
# Check title lengths

print("Title lengths:")
lengths = recipe_df['Title'].str.len()
print(lengths.describe())
# Out:
# Title lengths:
# count    13496.000000
# mean        32.761633
# std         14.756405
# min          3.000000
# 25%         21.000000
# 50%         31.000000
# 75%         43.000000
# max        112.000000
# Name: Title, dtype: float64

# %%
#explore the Cleaned_Ingredients column
#print first row of Cleaned_Ingredients
recipe_df['Cleaned_Ingredients'][1]
# Out:
# "['2 large egg whites', '1 pound new potatoes (about 1 inch in diameter)', '2 teaspoons kosher salt', '¾ teaspoon finely ground black pepper', '1 teaspoon finely chopped rosemary', '1 teaspoon finely chopped thyme', '1 teaspoon finely chopped parsley']"

# %%
#more information about the Cleaned_Ingredients column
#Cleaned_Ingredients value count
print('Cleaned_Ingredients value count:')
print(recipe_df['Cleaned_Ingredients'].value_counts())

#more information about the Cleaned_Ingredients column
print('Cleaned Ingredients describe:')
print(recipe_df['Cleaned_Ingredients'].describe())
# Out:
# Cleaned_Ingredients value count:
# ['']                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          12
# ...

# %%
#preprocessing
#clean the data to be able to work better with it and get more accurate result

# %%
#delete rows that have non values
recipe_df.dropna(inplace=True)

#print the shape of dataframe
print('dataframe shape after droping non-values',recipe_df.shape)
# Out:
# dataframe shape after droping non-values (13493, 6)

# %%
#drop unnamed column
#recipe_df = recipe_df.drop([0],axis=1)

# %%
#turning every character in title to lower case for easier search
recipe_df['Title']=recipe_df['Title'].map(lambda x: x.lower())
#print first row of Title to check
recipe_df['Title'][1]
# Out:
# 'crispy salt and pepper potatoes'

# %%
#turning every character in Cleaned_Ingredients to lower case for easier search
recipe_df['Cleaned_Ingredients']=recipe_df['Cleaned_Ingredients'].map(lambda x: x.lower())
#print first row of Cleaned_Ingredients to check
recipe_df['Cleaned_Ingredients'][1]
# Out:
# "['2 large egg whites', '1 pound new potatoes (about 1 inch in diameter)', '2 teaspoons kosher salt', '¾ teaspoon finely ground black pepper', '1 teaspoon finely chopped rosemary', '1 teaspoon finely chopped thyme', '1 teaspoon finely chopped parsley']"

# %%
#search based on title
#check for a specific word in the title of the food

recipe_title = input("what kind of food are you looking for?")
print(recipe_title)
# Out:
# what kind of food are you looking for?soup
# soup

# %%
#search for any row in dataframe contain user's desired food in title
recipe_df[recipe_df['Title'].str.contains(recipe_title)]
#(recipe_df['Title'].eq(recipe_title)).any()


#recipe_title["Indexes"]= recipe_title["Title"].str.find(recipe_title)
#recipe_title[recipe_title['Title'].str.contains("recipe_title")]
#recipe_df['Title'].find(recipe_title)
# Out:
#        Unnamed: 0                                      Title  \
# 12             12            butternut squash and apple soup
# 27             27                 spicy coconut pumpkin soup
# 50             50  summer bean soup with tomato brown butter
# 326           326      chicken-lentil soup with jammy onions
# 363           363                         chicken peppersoup
# ...           ...                                        ...
# 13382       13382            butternut squash and apple soup
# 13394       13394        pasta and cauliflower soup federica
# 13401       13401           thai-style chicken and rice soup
# 13476       13476       black bean soup with chipotle chiles
# 13478       13478                          cold avocado soup
#
#                                              Ingredients  \
# 12     ['6 slices bacon, cut crosswise into ½-inch pi...
# 27     ['2 tablespoons coconut oil', '1 pound calabaz...
# 50     ['8 oz. (230 g) dried beans, such as flageolet...
# ...

# %%
#search based on ingrediants
#search for a specific word in the ingrediants of the food

recipe_ingrediants = input("what kind of ingrediants are you looking for in the recipe?")
print(recipe_ingrediants)
# Out:
# what kind of ingrediants are you looking for in the recipe?lamb
# lamb

# %%
#search for any row in dataframe contain user's desired ingrediants in Cleaned_Ingredients

recipe_df[recipe_df['Cleaned_Ingredients'].str.contains(recipe_ingrediants)]
# Out:
#        Unnamed: 0                                              Title  \
# 8               8                            instant pot lamb haleem
# 58             58                  spiced lamb and dill yogurt pasta
# 100           100  stuffed eggplants and zucchini in a rich tomat...
# 299           299      goat birria tacos with cucumber pico de gallo
# 378           378                    lamb and green squash dumplings
# ...           ...                                                ...
# 13294       13294  herbed rack of lamb with parsley, mint, and wa...
# 13373       13373               roast leg of lamb with fennel butter
# 13443       13443                       spicy lamb and chorizo chili
# 13444       13444                                     shepherd's pie
# 13454       13454                                braised beef cheeks
#
#                                              Ingredients  \
# 8      ['¾ cup assorted dals (such as chana dal, moon...
# ...

# %%
#check ingrediants for approved food or avoided food

# %%
#defining the function ingrediant_parser to preprocess the list of ingrediants

def ingredient_parser(ingreds):
    measures = [
        "teaspoon", "t", "tsp.", "tablespoon", "T", "tbl.", "tb", "tbsp.", "fluid ounce", "fl oz", "fl", "gill",
        "cup", "c", "pint", "p", "pt", "fl pt", "quart", "q", "qt", "fl qt", "gallon", "g", "gal", "ml",
        "milliliter", "millilitre", "cc", "mL", "l", "liter", "litre", "L", "dl", "deciliter", "decilitre",
        "dL", "bulb", "level", "heaped", "rounded", "whole", "pinch", "medium", "slice", "pound", "lb", "#",
        "ounce", "oz", "mg", "milligram", "milligramme", "g", "gram", "gramme", "kg", "kilogram", "kilogramme",
        "x", "of", "mm", "millimetre", "millimeter", "cm", "centimeter", "centimetre", "m", "meter", "metre",
        "inch", "in", "milli", "centi", "deci", "hecto", "kilo", "tsp", "tbsp", 
    ]
    words_to_remove = [
        "fresh", "minced", "chopped", "a", "red", "bunch", "and", "clove", "or", "leaf", "large", "extra",
        "sprig", "ground", "handful", "free", "small", "virgin", "range", "from", "dried", "sustainable", "black",
        "peeled", "higher", "welfare", "seed", "for", "finely", "freshly", "sea", "quality", "white", "ripe",
        "few", "piece", "source", "to", "organic", "flat", "smoked", "sliced", "green", "picked", "the", "stick",
        "plain", "plus", "mixed", "mint", "bay", "basil", "your", "cumin", "optional", "fennel", "serve",
        "mustard", "unsalted", "baby", "paprika", "fat", "ask", "natural", "skin", "roughly", "into", "such",
        "cut", "good", "brown", "grated", "trimmed", "oregano", "powder", "yellow", "dusting", "knob", "frozen",
        "on", "deseeded", "low", "runny", "balsamic", "cooked", "streaky", "nutmeg", "sage", "rasher", "zest",
        "pin", "groundnut", "breadcrumb", "turmeric", "halved", "grating", "stalk", "light", "tinned", "dry",
        "soft", "rocket", "bone", "colour", "washed", "skinless", "leftover", "splash", "removed", "dijon",
        "thick", "big", "hot", "drained", "sized", "chestnut", "watercress", "fishmonger", "english", "dill",
        "caper", "raw", "worcestershire", "flake", "cider", "cayenne", "leg", "pine", "wild", "if",
        "fine", "herb", "shoulder", "cube", "dressing", "with", "chunk", "spice", "thumb", "garam", "new",
        "little", "punnet", "peppercorn", "shelled", "saffron", "other", "salt", "olive", "taste", "can",
        "sauce", "water", "diced", "package", "italian", "shredded", "divided", "parsley", "vinegar", "all",
        "purpose", "crushed", "juice", "more", "coriander", "bell", "needed", "thinly", "boneless", "half",
        "thyme", "cubed", "cinnamon", "cilantro", "jar", "seasoning", "rosemary", "extract", "sweet", "baking",
        "beaten", "heavy", "seeded", "tin", "vanilla", "uncooked", "crumb", "style", "thin", "nut", "coarsely",
        "spring", "chili", "cornstarch", "strip", "rinsed", "cherry", "root", "quartered", "head", "softened", 
        "container", "crumbled", "frying", "lean", "cooking", "roasted", "warm", "whipping", "thawed", "corn",
        "pitted", "sun", "kosher", "bite", "toasted", "lasagna", "split", "melted", "degree", "lengthwise",
        "romano", "packed", "pod", "rom", "prepared", "juiced", "fluid", "floret", "room", "active", "seasoned",
        "mix", "deveined", "lightly", "anise", "thai", "size", "unsweetened", "torn", "wedge", "sour", "dark",
        "temperature", "garnish", "bouillon", "loaf", "shell", "canola", "round", "canned", "ghee", "crust",
        "long", "broken", "ketchup", "bulk", "cleaned", "condensed", "sherry", "cold", "soda", "cottage",
        "spray", "shortening", "part", "bottle", "sodium", "grain", "french", "roast", "stem", "link", "firm",
        "asafoetida", "mild", "dash", "boiling", "oil", "chopped", "vegetable oil", "chopped oil", "garlic",
        "skin off", "bone", "out", "from", "sustrainable", "sources", "gala", "pink", "about", "serving", "at",
        "sharp", "sturdy", "reduced", "shallow", "ceramic", "glass", "dish", "pat", "depending", "sweetness",
        "wheel", "dehydrated", "basic", "like", "finishing", "hickory", "uncured", "smooth", "grainy", 
        "crosswise", "mashed", "paste", "country", "pale", "until", "run", "clear", "fillet", "tender", 
        "mexico", "john", "cope", "their", "ear", "blend", "choice", "there", "is", "full", "recipe", "our",
        "favorite", "iceberg", "bag", "kettle", "excess", "julienned", "including", "xuxu", "striped",
        "scored", "place", "each", "side", "salted", "soaked", "brined", "very", "meyer", "drizzling",
        "loosely", "single", "pie", "thread", "scissors", "tree", "reserved", "coarse", "discarded",
        "nonstick", "center", "percent", "california", "dime", "but", "one", "live", "pre", "spiced",
        "day", "breakfast", "fraiche", "bitter", "casing", "trimming", "homemade", "irish", "corned", "peel",
        "patted", "assorted", "dice", "stemmed", "vegetable", "bittersweet", "semisweet", "diameter", "pareve",
        "golden", "top", "waxy", "ingredient", "unpeeled", "purchased", "blanched", "available", "powdered",
        "chilled", "regular", "loose", "gently", "smashed", "square", "pullman", "swiss", "granulated", "any",
        "pressed", "confectioner", "mini", "destemmed", "scrubbed", "hothouse", "snap", "preferably",
        "separated", "only", "surface", "sheet", "substitute", "added", "liquid", "can", "spanish", "pain",
        "horizontally", "over", "turkish", "skinned", "heaping", "wheat", "lightlife", "chile", "holland",
        "overnight", "are", "crumble", "de", "hand", "see", "cook", "note", "neutral", "left", "intact",
        "bottled", "not", "box", "shichimi", "togarashi", "cracked", "slow", "apart", "wooden", "layer", 
        "instant", "bit", "boiled", "minute", "reserving", "asian", "wax", "enriched", "fingerling", "wide",
        "protein", "diagonal", "metal", "flaky", "then", "unseasoned", "hole", "grater", "button", "ice", "king",
        "arthur", "some", "core", "attached", "grill", "basket", "jumbo", "heirloom", "two", "chard",
        "unbleached", "mortar", "pure", "sold", "specialty", "food", "store", "bottom", "rolling", "cored",
        "gold", "feather", "quill", "tweezer", "needlenose", "gizzard", "most", "market", "latin", "diagonally", 
        "making", "quick", "liver", "reserve", "another", "blood", "an", "electric", "imported", "eight",
        "equivalent", "amount", "smaller", "first", "second", "peeler",
    ]

    #check if the ingrediants is a list and if not turn it into a list
    if isinstance(ingreds, list):
        ingredients = ingreds
    else:
        ingredients = ast.literal_eval(ingreds)
    
    # use translator to remove punctuations
    translator = str.maketrans("", "", string.punctuation)
    #lemmitiation: grouping together the different inflected forms of a word so they can be analyzed as a single item
    lemmatizer = WordNetLemmatizer()
    
    ingred_list = []
    for i in ingredients:
        i.translate(translator)
        # split up with hyphens and spaces
        items = re.split(" |-", i)
        # remove words containing non alphabet letters
        items = [word for word in items if word.isalpha()]
        # turn everything to lowercase
        items = [word.lower() for word in items]
        # remove accents
        items = [unidecode.unidecode(word) for word in items] 
        # Lemmatize words so we can compare words to measuring words
        items = [lemmatizer.lemmatize(word) for word in items]
        # remove measuring words/phrases based on the measures list we defined
        items = [word for word in items if word not in measures]
        # remove common easy words based on the words to remove list we defined
        items = [word for word in items if word not in words_to_remove]
        
        if items:
            ingred_list.append(" ".join(items))
    
    return ingred_list

# %%
#preprocess the list of ingrediants using the ingrediant_parser function
recipe_df['Ingredients_Parsed']=recipe_df['Cleaned_Ingredients'].apply(lambda x: ingredient_parser(x))

#print first row of Ingredients_Parsed to check
#recipe_df['Ingredients_Parsed'][0]
recipe_df['Ingredients_Parsed']
# Out:
# 0        [chicken, acorn squash, allspice, pepper, pepp...
# 1                                    [egg, potato, pepper]
# 2        [evaporated milk, milk, onion, pepper, cream c...
# 3        [celery, turkey giblet stock chicken broth, pa...
# 4        [sugar, bourbon, lemon, apple butter, orange t...
#                                ...
# 13496    [flour, cocoa, double acting, egg, sugar, cool...
# 13497    [preserved lemon, butternut, israeli couscous ...
# 13498    [katsuo bushi bonito dashi katsuo bushi, sake,...
# 13499                         [butter, spinach, by phyllo]
# 13500    [poblano, tomato, sugar, cream, goat cheese, r...
# Name: Ingredients_Parsed, Length: 13493, dtype: object

# %%
# save the preprocessed dataframe as acsv file
preprocessed_df = recipe_df[['Title', 'Ingredients_Parsed', 'Cleaned_Ingredients', 'Instructions']]
preprocessed_df.to_csv("../dataset/processed/preprocessed_ingredients_recipes.csv", index=False)
